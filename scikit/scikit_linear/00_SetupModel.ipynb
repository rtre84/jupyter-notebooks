# %%
# %%bash
#
# [ -s ./requirements_conda.txt ] && conda install --yes --file ./requirements_conda.txt
#
# [ -s ./requirements.txt ] && pip install -r ./requirements.txt
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda:
#
# The following NEW packages will be INSTALLED:
#
#     blas:         1.1-openblas       conda-forge
#     dill:         0.2.5-py35_1       conda-forge
#     openblas:     0.2.19-2           conda-forge
#     scikit-learn: 0.18.1-np113py35_1
#     ujson:        1.35-py35_0
#
# The following packages will be UPDATED:
#
#     gsl:          2.1-2              conda-forge --> 2.2.1-blas_openblas_2         conda-forge [blas_openblas]
#     scipy:        0.19.1-np113py35_0             --> 0.19.1-py35_blas_openblas_202 conda-forge [blas_openblas]
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#     numpy:        1.13.1-py35_0                  --> 1.13.0-py35_blas_openblas_200 conda-forge [blas_openblas]
#
# The following packages will be DOWNGRADED:
#
#     pandas:       0.20.3-py35_1      conda-forge --> 0.20.2-np113py35_1            conda-forge
#
# openblas-0.2.1 100% |###############################| Time: 0:00:03   3.87 MB/s
# blas-1.1-openb 100% |###############################| Time: 0:00:00   2.08 MB/s
# dill-0.2.5-py3 100% |###############################| Time: 0:00:00   3.12 MB/s
# ujson-1.35-py3 100% |###############################| Time: 0:00:00   3.15 MB/s
# gsl-2.2.1-blas 100% |###############################| Time: 0:00:02   3.13 MB/s
# numpy-1.13.0-p 100% |###############################| Time: 0:00:01   5.66 MB/s
# pandas-0.20.2- 100% |###############################| Time: 0:00:02   9.36 MB/s
# scipy-0.19.1-p 100% |###############################| Time: 0:00:04  10.09 MB/s
# scikit-learn-0 100% |###############################| Time: 0:00:01   7.82 MB/s
